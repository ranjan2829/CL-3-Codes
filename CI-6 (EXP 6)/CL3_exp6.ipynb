# %%
import numpy as np

# Objective function (minimize distance from 3)
def objective_function(x):
    return np.sum((x - 3)**2)

# 1. Initialize population (0-10 only)
def initialize_population(pop_size, dim):
    return np.random.uniform(0, 10, (pop_size, dim))

# 2. Calculate fitness
def calculate_fitness(population):
    return np.apply_along_axis(objective_function, 1, population)

# 3. Select top antibodies
def select_antibodies(population, fitness, num_selected):
    sorted_idx = np.argsort(fitness)
    return population[sorted_idx[:num_selected]]

# 4. Clone selected antibodies
def clone_antibodies(selected, clone_factor):
    return np.repeat(selected, clone_factor, axis=0)

# 5. Mutate clones (no negative values)
def mutate_clones(clones, mutation_rate):
    mutations = np.random.uniform(-mutation_rate, mutation_rate, clones.shape)
    mutated = clones + mutations
    return np.clip(mutated, 0, 10)  # Ensure 0-10 range

# 6. Select next generation
def select_next_generation(population, clones, pop_size):
    combined = np.vstack((population, clones))
    combined_fitness = calculate_fitness(combined)
    best_indices = np.argsort(combined_fitness)[:pop_size]
    return combined[best_indices]

# Main algorithm
def clonal_selection(pop_size=50, num_gen=50, dim=5, clone_factor=5, mutation_rate=0.2):
    # Initialize
    pop = initialize_population(pop_size, dim)
    best_sol = None
    best_fit = float('inf')
    
    for _ in range(num_gen):
        # Evaluate
        fitness = calculate_fitness(pop)
        
        # Track best
        if fitness[0] < best_fit:
            best_sol = pop[0].copy()
            best_fit = fitness[0]
        
        # Selection
        selected = select_antibodies(pop, fitness, pop_size//2)
        
        # Cloning
        clones = clone_antibodies(selected, clone_factor)
        
        # Mutation (with 0-10 bounds)
        clones = mutate_clones(clones, mutation_rate)
        
        # Next generation
        pop = select_next_generation(pop, clones, pop_size)
        print(f'Best fitness in generation {_}: {best_fit}')

    
    return best_sol, best_fit

# Run and print results
solution, fitness = clonal_selection()
print('Best Solution:', solution)
print('Fitness:', fitness)
# Out:
# Best fitness in generation 0: 53.13296967663432
# Best fitness in generation 1: 6.944854577359251
# Best fitness in generation 2: 6.027703727343509
# Best fitness in generation 3: 5.407396751549529
# Best fitness in generation 4: 4.604147997538018
# Best fitness in generation 5: 3.540056851398524
# Best fitness in generation 6: 2.8942383621390624
# Best fitness in generation 7: 2.477877437080566
# Best fitness in generation 8: 1.835103836721644
# Best fitness in generation 9: 1.1930062808973492
# Best fitness in generation 10: 0.7268026533692548
# Best fitness in generation 11: 0.5341162603404271
# Best fitness in generation 12: 0.44831174729811274
# Best fitness in generation 13: 0.28436780533108996
# Best fitness in generation 14: 0.13206511812100774
# Best fitness in generation 15: 0.12783039928636836
# Best fitness in generation 16: 0.02186317282659588
# Best fitness in generation 17: 0.01731701526048953
# Best fitness in generation 18: 0.01731701526048953
# Best fitness in generation 19: 0.01292257808195749
# Best fitness in generation 20: 0.002161078342659012
# Best fitness in generation 21: 0.002161078342659012
# Best fitness in generation 22: 0.002161078342659012
# Best fitness in generation 23: 0.002161078342659012
# Best fitness in generation 24: 0.002161078342659012
# Best fitness in generation 25: 0.002161078342659012
# Best fitness in generation 26: 0.002161078342659012
# Best fitness in generation 27: 0.002161078342659012
# Best fitness in generation 28: 0.002161078342659012
# Best fitness in generation 29: 0.002161078342659012
# Best fitness in generation 30: 0.002161078342659012
# Best fitness in generation 31: 0.002161078342659012
# Best fitness in generation 32: 0.002161078342659012
# Best fitness in generation 33: 0.002161078342659012
# Best fitness in generation 34: 0.002161078342659012
# Best fitness in generation 35: 0.002161078342659012
# Best fitness in generation 36: 0.002161078342659012
# Best fitness in generation 37: 0.002161078342659012
# Best fitness in generation 38: 0.0012502444837692766
# Best fitness in generation 39: 0.0012502444837692766
# Best fitness in generation 40: 0.0012502444837692766
# Best fitness in generation 41: 0.0012502444837692766
# Best fitness in generation 42: 0.0012502444837692766
# Best fitness in generation 43: 0.0012502444837692766
# Best fitness in generation 44: 0.0012502444837692766
# Best fitness in generation 45: 0.0012502444837692766
# Best fitness in generation 46: 0.0012502444837692766
# Best fitness in generation 47: 0.0012502444837692766
# Best fitness in generation 48: 0.0012502444837692766
# Best fitness in generation 49: 0.0012502444837692766
# Best Solution: [2.98611731 2.97482714 2.98151642 3.00749993 3.00509424]
# Fitness: 0.0012502444837692766
